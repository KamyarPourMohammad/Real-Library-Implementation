# %%
# inital implementation of a library
# this library in defined with Admin pannel
class Library:
    list_books=[]
    def __init__(self,name,established_year):
        self.name=name
        self.established_year=established_year
        
    def add_book(self, new_book):
        self.list_books.append(new_book)

    def del_book(self, old_book):
        self.list_books.remove(old_book)
    
    def list_of_books(self):
        return self.list_books

    def number_of_books(self):
        return len(self.list_books)

    def check_availability(self, book):
        if book in self.list_books:
            return True
        else:
            return False
    def 

#obj=Library('ali',1999)
#obj.add_book('serous')
#obj.list_of_books()
# Out:
# ['serous']

# %%
class Admin:
    global library_object
    
    def __init__(self,admin_name,admin_age):
        self.admin_name=admin_name
        self.admin_age=admin_age

    def create_library(self):
        library_name=input('input your library name')
        library_object=Library(library_name,2025)

# %%
def run_app():
    print('enter your name dear Admin!')
    name=input()
    print('and also your age!')
    age=int(input())
    admin_obj=Admin(name,age)
    print('admin profile is created successfully')

    while(True):
        print('do you want to make a library? y/n')
        x=input()
        if x=='y':
            print('ok')
            admin_obj.create_library()
            print('created successfully')
           
        elif x=='n':
            print('see you')
            break
        else:
            print('invalid input')
        

if __name__=='__main__':
    run_app()
# Out:
# enter your name dear Admin!
#  ee
# and also your age!
#  18
# admin profile is created successfully
# do you want to make a library? y/n
#  ss
# invalid input
# do you want to make a library? y/n
#  jfsnc
# invalid input
# do you want to make a library? y/n
#  n
# see you
